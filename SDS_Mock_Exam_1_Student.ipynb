# %% [markdown]
# # SDS Mock Comprehensive Exam 1 - Student Notebook
#
# **Time:** 4 hours
# **Points:** 100
# **Rule:** use built-in Apache Spark libraries only for scalable implementation tasks. Do not open the solution notebook during a timed attempt.

# %% [markdown]
# ## Setup
# Place the five CSV files from the mock pack in the same directory as this notebook, or edit `DATA_DIR`. Run this setup cell before starting.

# %%
from pathlib import Path
DATA_DIR = Path('.')

# Start/reuse Spark.
from pyspark.sql import SparkSession, functions as F
spark = SparkSession.builder.appName('SDS-Mock1').getOrCreate()

print('Spark version:', spark.version)
print('Data dir:', DATA_DIR.resolve())

# %% [markdown]
# ---
# # Problem 1 - Hashing and Locality-Sensitive Hashing [25 pts]
#
# See the student DOCX for the full wording.

# %% [markdown]
# ## 1a [8] Critique random-hyperplane LSH for Jaccard

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 1b [7] Design and verify a 60-row MinHash banding scheme

# %%
# Use this cell for calculations.
# Show the candidate-probability formula and verify both thresholds.

# %% [markdown]
# ## 1c [10] Spark MinHashLSH near-duplicate discovery

# %%
# Your Spark solution here.

# %% [markdown]
# ---
# # Problem 2 - Stream Mining [25 pts]

# %% [markdown]
# ## 2a [8] Count-Min Sketch sizing and Spark-safe construction

# %%
# Parameter calculations and/or implementation here.

# %% [markdown]
# ## 2b [6] AMS F2

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 2c [6] DGIM

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 2d [5] Exponential decay

# %% [markdown]
# **Answer:**

# %% [markdown]
# ---
# # Problem 3 - Link Analysis [25 pts]

# %% [markdown]
# ## 3a [15] Weighted topic-sensitive PageRank

# %%
# Your Spark solution here.

# %% [markdown]
# ## 3b [6] Critique the flawed PageRank idea

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 3c [4] PageRank versus HITS

# %% [markdown]
# **Answer:**

# %% [markdown]
# ---
# # Problem 4 - Social/Community Graph Mining [25 pts]

# %% [markdown]
# ## 4a [10] Direct K_{2,t} biclique-seed discovery

# %%
# Your Spark solution here.

# %% [markdown]
# ## 4b [8] Clique percolation and overlapping communities

# %% [markdown]
# **Answer:**

# %% [markdown]
# ## 4c [7] Spectral partitioning recognition and scalability

# %% [markdown]
# **Answer:**

# %% [markdown]
# ---
# # Final audit
# Before stopping, check: algorithm match, formulas, parameter verification, convergence, Spark boundary, sanity checks.
